# %%
from linkml_runtime.utils.schemaview import SchemaView
from linkml_runtime.dumpers import yaml_dumper

# %%
# or https://w3id.org/linkml/meta
schema_source = "https://raw.githubusercontent.com/linkml/linkml-model/refs/heads/main/linkml_model/model/schema/meta.yaml"

# %%
schema_view = SchemaView(schema_source, merge_imports=True)

# %%
sd = schema_view.induced_class("schema_definition")

# %%
sd_slots = sorted(sd.attributes.keys())

# %%
sd_slots
# Out:
# ['aliases',
#  'alt_descriptions',
#  'annotations',
#  'bindings',
#  'broad mappings',
#  'categories',
#  'classes',
#  'close mappings',
#  'comments',
#  'conforms_to',
#  'contributors',
#  'created_by',
#  'created_on',
#  'default_curi_maps',
#  'default_prefix',
#  'default_range',
#  'definition_uri',
#  'deprecated',
#  'deprecated element has exact replacement',
#  'deprecated element has possible replacement',
#  'description',
#  'emit_prefixes',
#  'enums',
#  'exact mappings',
#  'examples',
#  'extensions',
#  'from_schema',
#  'generation_date',
#  'id',
#  'id_prefixes',
#  'id_prefixes_are_closed',
#  'implements',
#  'imported_from',
#  'imports',
#  'in_language',
#  'in_subset',
#  'instantiates',
#  'keywords',
#  'last_updated_on',
#  'license',
#  'local_names',
#  'mappings',
#  'metamodel_version',
#  'modified_by',
#  'name',
#  'narrow mappings',
#  'notes',
#  'prefixes',
#  'rank',
#  'related mappings',
#  'see_also',
#  'settings',
# ...

# %%
yaml_dumper.dumps(schema_view)
# Out:
# ---------------------------------------------------------------------------
# RepresenterError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 yaml_dumper.dumps(schema_view)
#
# File ~/Documents/gitrepos/compare-mixs/main/mixs/.venv/lib/python3.11/site-packages/linkml_runtime/dumpers/yaml_dumper.py:17, in YAMLDumper.dumps(self, element, **kwargs)
#      13 # Internal note: remove_empty_items will also convert Decimals to int/float;
#      14 # this is necessary until https://github.com/yaml/pyyaml/pull/372 is merged
#      16 dumper_safe_element = element.model_dump() if isinstance(element, BaseModel) else element
# ---> 17 return yaml.dump(remove_empty_items(dumper_safe_element, hide_protected_keys=True),
#      18                  Dumper=yaml.SafeDumper, sort_keys=False,
#      19                  allow_unicode=True,
#      20                  **kwargs)
#
# ...
